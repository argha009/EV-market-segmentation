# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Indian_automoble_buying_behavour_study.csv')
df.head()
# Out:
#    Age Profession Marrital Status      Education  No of Dependents  \
# 0   27   Salaried          Single  Post Graduate                 0
# 1   35   Salaried         Married  Post Graduate                 2
# 2   45   Business         Married       Graduate                 4
# 3   41   Business         Married  Post Graduate                 3
# 4   31   Salaried         Married  Post Graduate                 2
#
#   Personal loan House Loan Wife Working   Salary  Wife Salary  Total Salary  \
# 0           Yes         No           No   800000            0        800000
# 1           Yes        Yes          Yes  1400000       600000       2000000
# 2           Yes        Yes           No  1800000            0       1800000
# 3            No         No          Yes  1600000       600000       2200000
# 4           Yes         No          Yes  1800000       800000       2600000
#
#      Make    Price
# 0     i20   800000
# 1    Ciaz  1000000
# 2  Duster  1200000
# 3    City  1200000
# ...

# %%
df.shape
# Out:
# (99, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               99 non-null     int64
#  1   Profession        99 non-null     object
#  2   Marrital Status   99 non-null     object
#  3   Education         99 non-null     object
#  4   No of Dependents  99 non-null     int64
#  5   Personal loan     99 non-null     object
#  6   House Loan        99 non-null     object
#  7   Wife Working      99 non-null     object
#  8   Salary            99 non-null     int64
#  9   Wife Salary       99 non-null     int64
#  10  Total Salary      99 non-null     int64
#  11  Make              99 non-null     object
#  12  Price             99 non-null     int64
# dtypes: int64(6), object(7)
# memory usage: 10.2+ KB

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.Age.unique()
# Out:
# array([27, 35, 45, 41, 31, 28, 33, 34, 29, 30, 49, 26, 37, 36, 43, 42, 32,
#        44, 39, 46, 50, 51], dtype=int64)

# %%
sns.countplot(data=df,x='Age')
plt.title('Agewise variation countplot')
# Out:
# Text(0.5, 1.0, 'Agewise variation countplot')

# %%
df['No of Dependents'].unique()
# Out:
# array([0, 2, 4, 3], dtype=int64)

# %%
sns.distplot(df.Salary)
# Out:
# C:\Users\Argha009\AppData\Local\Temp\ipykernel_7784\3806395495.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Salary)
# <Axes: xlabel='Salary', ylabel='Density'>

# %%
plt.hist(df.Salary)
plt.title('Histogram plot for Salary')
# Out:
# Text(0.5, 1.0, 'Histogram plot for Salary')

# %%
sns.catplot(data=df,x='Profession',y='Salary',kind='bar',height=4.5,aspect=2)
sns.despine(right=False,top=False)
plt.tick_params(axis='x',rotation=40)

# %%
sns.catplot(data=df,x='Education',y='Salary',kind='bar',height=4.5,aspect=2)
sns.despine(right=False,top=False)
plt.tick_params(axis='x',rotation=40)

# %%
sns.catplot(data=df,x='Make',y='Salary',kind='bar',height=4.5,aspect=2)
sns.despine(right=False,top=False)
plt.tick_params(axis='x',rotation=40)

# %%
sns.violinplot(data=df,x='Age',y='Make')
# Out:
# <Axes: xlabel='Age', ylabel='Make'>

# %%
sns.violinplot(data=df,x='Salary',y='Make')
# Out:
# <Axes: xlabel='Salary', ylabel='Make'>

# %%
sns.violinplot(data=df,x='Wife Salary',y='Make')
# Out:
# <Axes: xlabel='Wife Salary', ylabel='Make'>

# %%
sns.violinplot(data=df,x='No of Dependents',y='Make')
# Out:
# <Axes: xlabel='No of Dependents', ylabel='Make'>

# %%
sns.violinplot(data=df,x='Total Salary',y='Make')
# Out:
# <Axes: xlabel='Total Salary', ylabel='Make'>

# %%
sns.violinplot(data=df,x='Price',y='Make')
# Out:
# <Axes: xlabel='Price', ylabel='Make'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\Argha009\AppData\Local\Temp\ipykernel_7784\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >
