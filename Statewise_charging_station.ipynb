# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel('2_ev_charging_station_dataset.xlsx',sheet_name='Table 4',skiprows=1)
df
# Out:
#              State/UT  EV Charging Facility
# 0      Andhra Pradesh                    65
# 1   Arunachal Pradesh                     4
# 2               Assam                    19
# 3               Bihar                    26
# 4          Chandigarh                     4
# 5        Chhattisgarh                    51
# 6               Delhi                    66
# 7                 Goa                    17
# 8             Gujarat                    87
# 9             Haryana                   114
# 10   Himachal Pradesh                    13
# 11          Jharkhand                    22
# 12                J&K                     3
# 13          Karnataka                   100
# 14             Kerala                    39
# 15                Leh                     2
# 16     Madhya Pradesh                   167
# 17         Maharastra                    88
# 18            Manipur                     1
# 19          Meghalaya                     3
# ...

# %%
df.isnull().sum()
# Out:
# State/UT                0
# EV Charging Facility    0
# dtype: int64

# %%
plt.figure(figsize=(6,6))
sns.pointplot(data=df,x='EV Charging Facility',y='State/UT',color='g')

plt.title('Statewise EV Charging facility')

plt.savefig('9.png')
